# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/content/penguins_binary_classification.csv")
df
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g  year
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0  2007
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  2007
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  2007
# 3    Adelie  Torgersen            36.7  ...              193.0       3450.0  2007
# 4    Adelie  Torgersen            39.3  ...              190.0       3650.0  2007
# ..      ...        ...             ...  ...                ...          ...   ...
# 269  Gentoo     Biscoe            47.2  ...              214.0       4925.0  2009
# 270  Gentoo     Biscoe            46.8  ...              215.0       4850.0  2009
# 271  Gentoo     Biscoe            50.4  ...              222.0       5750.0  2009
# 272  Gentoo     Biscoe            45.2  ...              212.0       5200.0  2009
# ...

# %%
df.describe(include="all")
# Out:
#        species  island  ...  body_mass_g         year
# count      274     274  ...   274.000000   274.000000
# unique       2       3  ...          NaN          NaN
# top     Adelie  Biscoe  ...          NaN          NaN
# freq       151     167  ...          NaN          NaN
# mean       NaN     NaN  ...  4318.065693  2008.043796
# std        NaN     NaN  ...   835.933105     0.806281
# min        NaN     NaN  ...  2850.000000  2007.000000
# 25%        NaN     NaN  ...  3600.000000  2007.000000
# 50%        NaN     NaN  ...  4262.500000  2008.000000
# 75%        NaN     NaN  ...  4950.000000  2009.000000
# max        NaN     NaN  ...  6300.000000  2009.000000
#
# [11 rows x 7 columns]

# %%
df['island'] = df['island'].map({'Torgersen':0,'Biscoe':1,'Dream':2})

# %%
df.head()
# Out:
#   species  island  bill_length_mm  ...  flipper_length_mm  body_mass_g  year
# 0  Adelie       0            39.1  ...              181.0       3750.0  2007
# 1  Adelie       0            39.5  ...              186.0       3800.0  2007
# 2  Adelie       0            40.3  ...              195.0       3250.0  2007
# 3  Adelie       0            36.7  ...              193.0       3450.0  2007
# 4  Adelie       0            39.3  ...              190.0       3650.0  2007
#
# [5 rows x 7 columns]

# %%
df.describe(include="all")
# Out:
#        species      island  ...  body_mass_g         year
# count      274  274.000000  ...   274.000000   274.000000
# unique       2         NaN  ...          NaN          NaN
# top     Adelie         NaN  ...          NaN          NaN
# freq       151         NaN  ...          NaN          NaN
# mean       NaN    1.018248  ...  4318.065693  2008.043796
# std        NaN    0.625785  ...   835.933105     0.806281
# min        NaN    0.000000  ...  2850.000000  2007.000000
# 25%        NaN    1.000000  ...  3600.000000  2007.000000
# 50%        NaN    1.000000  ...  4262.500000  2008.000000
# 75%        NaN    1.000000  ...  4950.000000  2009.000000
# max        NaN    2.000000  ...  6300.000000  2009.000000
#
# [11 rows x 7 columns]

# %%
df.drop(['year','island'],axis=1,inplace=True)

# %%
X = df.drop('species',axis=1)
Y = df['species']

# %%
X_train , x_test , Y_train , y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
log_model = LogisticRegressionCV(Cs=[1,10,50,100,150,1000],max_iter=1000)

# %%
log_model.fit(X_train,Y_train)
# Out:
# LogisticRegressionCV(Cs=[1, 10, 50, 100, 150, 1000], max_iter=1000)

# %%
log_model.coef_
# Out:
# array([[ 0.34602084, -2.05992257,  0.48500271,  0.00640699]])

# %%
log_model.C_
# Out:
# array([10])

# %%
y_pred = log_model.predict(x_test)

# %%
y_pred_proba = log_model.predict_proba(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        30
#       Gentoo       1.00      1.00      1.00        25
#
#     accuracy                           1.00        55
#    macro avg       1.00      1.00      1.00        55
# weighted avg       1.00      1.00      1.00        55
